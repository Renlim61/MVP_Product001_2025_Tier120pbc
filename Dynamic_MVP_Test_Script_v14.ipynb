# %% [markdown]
# <a href="https://colab.research.google.com/github/Renlim61/MVP_Product001_2025_Tier120pbc/blob/version-history/Dynamic_MVP_Test_Script_v14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧪 v14 Test Execution Log & Structured Feedback
# Version: phase1_rag_mvp_v14
# Test Run ID: ___run1________
# Date: ___12/07/2025________
# Tester: _____lpm______
#
#
# # ====================================
# # A. ENVIRONMENT & LAUNCH
# # ====================================
#
# ## A1. Restart runtime
# - [X ] PASS   [ ] FAIL
# Status: __running____
# Notes: ______
#
# ## A2. Run all cells successfully
# - [X ] PASS   [ ] FAIL
# Status: ______
# Notes: ______
#
#
# # ====================================
# # B. IDENTITY & ROLE LOGIC
# # ====================================
#
# ## B1.1 Admin login works
# - [X ] PASS   [ ] FAIL
# Notes: ______
#
# ## B1.2 Demo login works
# - [X ] PASS   [ ] FAIL
# Notes: ______
#
# ## B2.1 Failed login produces correct error + audit entry
# - [ X] PASS   [ ] FAIL
# Notes: ______
#
#
# # ====================================
# # C. COHORT OWNERSHIP & VISIBILITY
# # ====================================
#
# ## C1.1 Admin builds cohort
# - [X ] PASS   [ ] FAIL
# Notes: ______
#
# ## C1.2 Admin sees own cohort
# - [ X] PASS   [ ] FAIL
# Notes: ______
#
# ## C2.1 Demo cannot see admin cohort
# - [ X] PASS   [ ] FAIL
# Notes: _one thing to note, maybe we should add a message when a user pulls up admin tab, saying something like __user does not have the level of persmisisons to access admin dashboard?___
#
# ## C3.1 Demo builds cohort
# - [X ] PASS   [ ] FAIL
# Notes: ___this may be a fail or just a situation we dod nto think of. When i built the cohort under the user id, the file the admin had uplaoded for their cohoprt was still in the lsit and when i built the user cohort it included that tile along with the file the user uplaoded.  we want the build cohort tasb to be cleaned oput of memory any time we endter the tab.  And it should definitely not add files there were picked from a previous session.___
#
# ## C3.2 Demo sees own cohort
# - [X ] PASS   [ ] FAIL
# Notes: ______
#
# ## C4.1 Admin sees all cohorts
# - [X ] PASS   [ ] FAIL
# Notes: __however, when we went into the ask question tab, it did not default to the current user.  in the production version once someone logs in they should be the user throughout the system until they logoff or another user/admin logs on.____
#
#
# # ====================================
# # D. Q&A + HISTORY
# # ====================================
#
# ## D1.1 Demo asks question successfully
# - [ X] PASS   [ ] FAIL
# Notes: ______
#
# ## D2.1 Chat history displays entry
# - [X ] PASS   [ ] FAIL
# Notes: ______
#
#
# # ====================================
# # E. ADMIN CAPABILITIES
# # ====================================
#
# ## E1.1 Admin overview loads stats correctly
# - [ X] PASS   [ ] FAIL
# Notes: ______
#
# ## E2.1 Admin sees both cohorts in delete dropdown
# - [X ] PASS   [ ] FAIL
# Notes: ______
#
# ## E2.2 Admin deletes demo cohort
# - [ X] PASS   [ ] FAIL
# Notes: ______
#
# ## E2.3 Demo no longer sees deleted cohort
# - [X ] PASS   [ ] FAIL
# Notes: ______
#
#
# # ====================================
# # F. AUDIT LOG
# # ====================================
#
# ## F1. Audit log contains expected entries:
# - login
# - login_failed
# - build_cohort
# - ask
# - view_history
# - delete_cohort
# - admin_refresh
#
# - [X ] PASS   [ ] FAIL
# Notes: ______
#
#
# # ====================================
# # G. RUNTIME CLEANLINESS
# # ====================================
#
# ## G1. No utcnow() warnings, no unexpected errors
# - [ X] PASS   [ ] FAIL
# Notes: ______
#
#
#
# # ============================================
# # H. STRUCTURED FEEDBACK CAPSULES (1 per issue)
# # ============================================
#
# # --- FEEDBACK ITEM #1 ---
# Issue ID: F-_001___
# Test Step: (C2.1 Demo cannot see admin cohort.)
# Observed Behavior:one thing to note, maybe we should add a message when a user pulls up admin tab, saying something like __user does not have the level of persmisisons to access admin dashboard?__
# Expected Behavior:  This is new functionality
# Error Traceback (if any):
# Screenshot Link (optional):
# Reproducibility: [ ] Always [ ] Sometimes [ ] Rare
# Severity: Minor
# Notes:
#
# # --- FEEDBACK ITEM #2 ---
# Issue ID: F-_002___
# Test Step:C3.1 Demo builds cohort
# Observed Behavior: this may be a fail or just a situation we did not think of. When i built the cohort under the user id, the file the admin had uploaded for their cohort was still in the list and when i built the user cohort it included that file along with the file the active user uploaded.
# Expected Behavior:  we want the build cohort tab to default to blank fields any time we enter the tab.  And it should definitely not add files that were uploaded from a previous session, that is a major security issue
# Error Traceback:
# Severity:  Major
# Notes:
#
# # --- FEEDBACK ITEM #3 ---
# Issue ID: F-003____
# Test Step:  C4.1 Admin sees all cohorts
# Observed Behavior: when we went into the ask question tab, it did not default to the current user.
# Expected Behavior:  in the production version once someone logs in they should be the user throughout the system until they logoff or another user/admin logs on.
# Error Traceback:
# Severity:  Major
# Notes:
#
#
#
# # ============================================
# # I. GLOBAL SUMMARY (Your own notes)
# # ============================================
#
# Overall stability: ______
# User experience rating: ______
# Performance notes: ______
# Recommended fixes or improvements: ______
#
#
#
# # ============================================
# # J. FEEDBACK TO CHATGPT (PASTE THIS SECTION)
# # ============================================
#
# When all tests are done, **copy/paste ONLY this section back to ChatGPT**:
#
# ------------------ BEGIN FEEDBACK TO CHATGPT ------------------
#
# **Test Summary for v14:**
# - Passes: ___
# - Fails: ___
# - Overall Stability: ___
# - Key Issues Found:
#   1. Issue ID F-_001__ → user message accessmessage when they enter admin tab
#   2. Issue ID F-_002__ → clear fileds/do not allow duplicate cohort namest
#   3. Issue ID F-003__ →  askquestion tab - default to current user
# - Attachments Provided: No
# - Additional Notes:all test have passed 2nd test cycle
# ___
#
# ------------------ END FEEDBACK TO CHATGPT ------------------
